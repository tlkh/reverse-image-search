# %%
# %run image_database_helper.ipynb
model = init_model()

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('index_subimage.csv')
# df.head()

feature_vectors = df['feature_vector'].apply(lambda x: 
                           np.fromstring(
                               x.replace('\n','')
                                .replace('[','')
                                .replace(']','')
                                .replace('  ',' '), sep=' '))
# ref: https://stackoverflow.com/questions/45704999/

# %%
df['img_file_name'][0]
# Out:
# 'our-singapore-malaysian-durian-fake-768x791.jpg'

# %%
images = findfiles("test/")
print(len(images))
# Out:
# 4

# %%
for img_name in images:
    path_image_to_analyse = "./test/"+img_name
    print(img_name)
    
    result = analyse_image(model, path_image_to_analyse, plotting=True)
    
    print("\n\n\n\n\n\n\n\n\n\n")
    
#     subprocess.run("mv ./new/{} ./database/{}".format(img_name,img_name),shell=True)
# Out:
# Screen Shot 2018-04-05 at 00.29.14 AM.png
# ============ FRAME ANALYSED =============
# ----------- NEAREST PICTURES ------------
# [33  6 15 42]
# 33
# percentage match: 0.7326321916372547
# 6
# percentage match: 0.7326321916372547
# 15
# percentage match: 0.6491763327135873
# 42
# percentage match: 0.6491763327135873
# Screen Shot 2018-04-05 at 00.29.55 AM.png
# ============ FRAME ANALYSED =============
# ----------- NEAREST PICTURES ------------
# [18 45 40 13]
# 18
# percentage match: 0.9980644164122089
# 45
# percentage match: 0.9980644164122089
# 40
# percentage match: 0.947355300887657
# 13
# percentage match: 0.947355300887657
# Screen Shot 2018-04-05 at 00.29.36 AM.png
# ============ FRAME ANALYSED =============
# ----------- NEAREST PICTURES ------------
# [21 48 25 52]
# 21
# percentage match: 0.6095112293556868
# 48
# percentage match: 0.6095112293556868
# 25
# percentage match: 0.6079183275198714
# 52
# percentage match: 0.6079183275198714
# ...
